# %%
import math
print(math.pi)

from math import e
print(math.e)

from math import degrees, radians
print(degrees(math.pi), radians(90))

from math import floor, ceil
print(floor(3.8), ceil(3.1))

from math import factorial
print(factorial(5))
# Out:
# 3.141592653589793
# 2.718281828459045
# 180.0 1.5707963267948966
# 3 4
# 120

# %%
import random as r

for i in range(3):
    print(r.random())

cards = [[1, '송학'], [2, '메조'], [3, '벚꽃'], [4, '흑싸리'], [5, '초'], [6, '모란']]
print(cards)
for _ in range(3):
    r.shuffle(cards)
    print(cards)

print(r.sample(cards, 2))
# Out:
# 0.00034068688102950606
# 0.8654028302132573
# 0.32950757747392334
# [[1, '송학'], [2, '메조'], [3, '벚꽃'], [4, '흑싸리'], [5, '초'], [6, '모란']]
# [[1, '송학'], [4, '흑싸리'], [2, '메조'], [3, '벚꽃'], [5, '초'], [6, '모란']]
# [[5, '초'], [3, '벚꽃'], [4, '흑싸리'], [1, '송학'], [6, '모란'], [2, '메조']]
# [[3, '벚꽃'], [4, '흑싸리'], [6, '모란'], [1, '송학'], [5, '초'], [2, '메조']]
# [[1, '송학'], [5, '초']]

# %%
import random as r
print(dir(r), end='')
# Out:
# ['BPF', 'LOG4', 'NV_MAGICCONST', 'RECIP_BPF', 'Random', 'SG_MAGICCONST', 'SystemRandom', 'TWOPI', '_ONE', '_Sequence', '_Set', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_accumulate', '_acos', '_bisect', '_ceil', '_cos', '_e', '_exp', '_floor', '_index', '_inst', '_isfinite', '_log', '_os', '_pi', '_random', '_repeat', '_sha512', '_sin', '_sqrt', '_test', '_test_generator', '_urandom', '_warn', 'betavariate', 'choice', 'choices', 'expovariate', 'gammavariate', 'gauss', 'getrandbits', 'getstate', 'lognormvariate', 'normalvariate', 'paretovariate', 'randbytes', 'randint', 'random', 'randrange', 'sample', 'seed', 'setstate', 'shuffle', 'triangular', 'uniform', 'vonmisesvariate', 'weibullvariate']

# %%
# ?dir
# Out:
# Docstring:
# dir([object]) -> list of strings
#
# If called without an argument, return the names in the current scope.
# Else, return an alphabetized list of names comprising (some of) the attributes
# of the given object, and of attributes reachable from it.
# If the object supplies a method named __dir__, it will be used; otherwise
# the default dir() logic is used and returns:
#   for a module object: the module's attributes.
#   for a class object:  its attributes, and recursively the attributes
#     of its bases.
#   for any other object: its attributes, its class's attributes, and
#     recursively the attributes of its class's base classes.
# Type:      builtin_function_or_method

# %%
# 사용자 정의 모듈 만들기

# 현재 작업 경로 확인
import os
print(f'{os.getcwd()}\n')



# 파이썬 절대경로를 통한 파일 읽어오기
f = open('C:/Users/User/Documents/embo.txt', 'r', encoding='utf-8')
data = f.read()
print(data)
f.close()
# Out:
# c:\PythonLanguage\chapter9
#
# 파이썬에서 사용자 정의 모듈을 사용하는 이유는 다음과 같습니다.
#
# 코드 재사용성 향상
# 사용자 정의 모듈을 사용하면 코드를 파일에 저장하여 다른 프로그램에서 재사용할 수 있습니다. 이렇게 하면 코드를 반복적으로 작성하지 않아도 되므로 코드의 재사용성과 유지보수성을 향상시킬 수 있습니다.
#
# 코드 가독성 향상
# 사용자 정의 모듈을 사용하면 코드를 기능별로 분리하여 작성할 수 있습니다. 이렇게 하면 코드가 더 가독성 있게 되고, 코드를 이해하고 유지보수하기가 더 쉬워집니다.
#
# 시스템 성능 향상
# 사용자 정의 모듈을 사용하면 코드를 로드할 때 한 번만 컴파일하면 됩니다. 이렇게 하면 시스템 성능을 향상시킬 수 있습니다.
#
# 라이브러리 확장
# 사용자 정의 모듈을 사용하여 파이썬 표준 라이브러리에 없는 기능을 추가할 수 있습니다. 이렇게 하면 파이썬의 기능을 확장할 수 있습니다.

# %%
import os
print(os.getcwd)

# %%
import hello
hello.hi()

# %%
from create import add
print(add)
# Out:
# 사용자 정의 모듈 생성 완료!!!

# %%
import sys
print(sys.path)

# %%
# 절대경로로 추가하는 방법
sys.path.append('C:\Python\Python38\Lib\site-packages')
sys.path

# %%
import sys
sys.path.append('C:/Users/User/Documents')
sys.path
# Out:
# ['c:\\PythonLanguage\\chapter9',
#  'c:\\Python\\Python311\\python311.zip',
#  'c:\\Python\\Python311\\DLLs',
#  'c:\\Python\\Python311\\Lib',
#  'c:\\Python\\Python311',
#  '',
#  'C:\\Users\\User\\AppData\\Roaming\\Python\\Python311\\site-packages',
#  'C:\\Users\\User\\AppData\\Roaming\\Python\\Python311\\site-packages\\win32',
#  'C:\\Users\\User\\AppData\\Roaming\\Python\\Python311\\site-packages\\win32\\lib',
#  'C:\\Users\\User\\AppData\\Roaming\\Python\\Python311\\site-packages\\Pythonwin',
#  'c:\\Python\\Python311\\Lib\\site-packages',
#  'C:/Users/User/Documents']

# %%
import turtle as t

for i in ("red", "yellow", "green", "blue"):
    t.speed(3)
    t.pensize(10)
    t.color(i)
    t.forward(300)
    t.right(90)
    
t.speed(3)
t.color("purple", "pink")
t.begin_fill()
t.right(-45)
t.forward(200)
t.right(90)
t.forward(200)
t.end_fill()

t.delay(10000)

t.clearscreen()

def on_click(x, y):
    t.bye()

t.onscreenclick(on_click)

# %%
import numpy as np

aryA = np.array([1,2,3,4,5])
aryB = np.array([6,7,8,9,10])

print(aryA + aryB)
print(aryA - aryB)
print(aryA * aryB)
print(aryA / aryB)
# Out:
# [ 7  9 11 13 15]
# [-5 -5 -5 -5 -5]
# [ 6 14 24 36 50]
# [0.16666667 0.28571429 0.375      0.44444444 0.5       ]

# %%
import matplotlib.pyplot as plt

plt.plot([2, 4, 6, 8], [8, 10, 3, 6])
plt.show()

# %%
# matlab-like plotting"
import matplotlib.pyplot as plt
object = ('Python', 'Java', 'C++', 'C#', 'C', 'Kotlin')
performance = [10, 8, 6, 4, 7, 2]

plt.title('Programming language usage')
plt.xlabel('Usage')
plt.ylabel('Programming Language')
plt.barh(object, performance, height=0.5, color='yellow')
plt.show()

# %%
import matplotlib.pyplot as plt

# 데이터 생성
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# 산점도 그리기
plt.scatter(x, y)

# 그래프 제목 설정
plt.title("relationship")

# 축 레이블 설정
plt.xlabel("x")
plt.ylabel("y")

# 그래프 표시
plt.show()

# %%
import matplotlib.pyplot as plt

# 데이터 생성
data = [25, 20, 15, 20]

# 원그래프 그리기
plt.pie(data)

# 그래프 제목 설정
plt.title("The relative size of the component")

# 범례 설정
plt.legend(["A", "B", "C", "D"])

# 그래프 표시
plt.show()

# %%
import matplotlib.pyplot as plt

# 데이터 생성
x = [0, 1, 2, 3, 4]
y = [20, 25, 30, 35, 40]

# 그래프 그리기
plt.plot(x, y)

# 제목 설정
plt.title("changing degree")

# 축 레이블 설정
plt.xlabel("time")
plt.ylabel("temperature")

# 그래프 표시
plt.show()

# %%
from datetime import date

today = date.today()
print(f'{today.year}년 {today.month}월 {today.day}일')

xmsday =date(2023, 12, 25)
delta = xmsday - today
print(delta.days)

from datetime import timedelta
date100 = timedelta(days=100)
after100 = today + date100
print(after100)

# %%
import turtle as t
colors = ["red", "purple", "blue", "green", "orange", "yellow"]
t.setup(500, 400)
t.bgcolor("black")
t.speed(3)
for i in range(180):
    t.pencolor(colors[i%len(colors)])
    t.width(i/100 + 1)
    t.forward(i)
    t.left(59)
t.onscreenclick

# %%
import math as m, random as rd

def getarea():
    return m.pi * (r**2)

r = (round(rd.random()* 10, 2))
print(f'원의 반지름: {r}')
print(f'원주율 pi: {m.pi:.4f}')
print(f'반지름 {r}인 원의 면적은 {getarea():.2f}')
# Out:
# 원의 반지름: 9.35
# 원주율 pi: 3.1416
# 반지름 9.35인 원의 면적은 274.65

# %%
import math as m, statistics as s
enter = (1, 6, 11, 16)

def ftl():
    for i in enter:
        ft = m.factorial(i)
        print(f'{i}! = {ft}')

ftl()
print()

st = [80, 99, 77, 65, 92, 74, 82]
if __name__ == '__main__':
    print(st)
    print(f'중앙 값: {s.median(st):.2f}')
    print(f'평균: {s.mean(st):.2f}')
    print(f'분산: {s.variance(st):.2f}')
    print(f'표준편차: {s.stdev(st):.2f}')
# Out:
# 1! = 1
# 6! = 720
# 11! = 39916800
# 16! = 20922789888000
#
# [80, 99, 77, 65, 92, 74, 82]
# 중앙 값: 80.00
# 평균: 81.29
# 분산: 127.90
# 표준편차: 11.31

# %%
import turtle as t

t.setup(500, 500)
t.bgcolor('black')
t.speed(0)
c = ['yellow', 'red', 'blue']
for i in range(200):
    t.pencolor(c[i%len(c)])
    t.pensize(i/200 + 1)
    t.forward(i * 2)
    t.left(119)
t.exitonclick()

# %% [markdown]
# - [터틀 그래픽] https://docs.python.org/ko/dev/library/turtle.html#turtle.exitonclick

# %%
import turtle as t

def drawpolygon(n, size):
    for i in range(n):
        t.forward(size)
        t.right(360/n)

t.setup(500, 500)
t.speed(1)
t.pu()
t.goto(-100, 0)
t.pd()
        
drawpolygon(5, 50)

t.exitonclick()

# %%
import turtle as t
from random import randint as r

t.setup(800, 500)
t.speed(1)
tshs = ['arrow', 'circle', 'turtle', 'square', 'triangle', 'classic']
han = ['화살', '원', '거북이', '사각형', '삼각형', '전통']
cols = ['red', 'blue', 'green', 'purple', 'magenta', 'black', 'gray', 'yellow', 'cyan', 'orange', 'aqua']

for i in range(20):
    half = r(3, 50)
    x = r(-300, 300)
    y = r(-200, 200)

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-np.pi*2, np.pi*2, 720)
cos, sin = np.cos(x), np.sin(x)

plt.plot(x, sin, ls=':', label='sin')
plt.plot(x, cos, ls='--', label='cos')

plt.title("Graph of sin cos")
plt.xlabel('radians')
plt.ylabel('value')
plt.grid()
plt.legend()
plt.show()
